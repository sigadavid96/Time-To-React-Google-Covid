# %%
# !pip install pytrends
# Out:
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16126 sha256=706c2024306905074d9124b6b0e1c955d1855df010851c0f8d62f9b57b95ddc5
#   Stored in directory: /root/.cache/pip/wheels/07/6f/5c/8174f98dec1bfbc7d5da4092854afcbcff4b26c3d9b66b5183
# Successfully built pytrends
# ...

# %%
import pandas as pd                        
from pytrends.request import TrendReq

# %%
pytrend = TrendReq(backoff_factor=0.1)

# %%
def get_historical_data_by_region(kw_list,region,sleep=0):
  historicaldf = pytrend.get_historical_interest(kw_list, year_start=2019, month_start=10, day_start=1, hour_start=0, year_end=2022, month_end=5, day_end=1, hour_end=0, cat=0, geo=region, gprop='', sleep=sleep)
  return historicaldf

# %% [markdown]
# Getting Related Queries to Get list of data for related queries

# %%
kw_list=['Covid', 'Coronavirus']
pytrend.build_payload(kw_list, timeframe='today 1-m')

related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                    query  value
# 0             covid test    100
# 1               covid 19     98
# 2            covid cases     70
# 3          covid vaccine     41
# 4             long covid     34
# 5         covid symptoms     33
# 6          covid testing     32
# 7            india covid     24
# 8             covid news     20
# 9          covid booster     19
# 10              us covid     17
# 11           covid rules     15
# 12        covid in india     15
# 13              uk covid     15
# 14          vacuna covid     14
# 15     covid cases today     13
# 16     covid cases india     13
# 17           covid delhi     12
# 18   positive covid test     11
# 19  covid cases in india     11
# 20          france covid     10
# 21          covid update     10
# 22             covid usa     10
# 23     covid vaccination      9
# 24     delhi covid cases      9, 'rising':                                           query  value
# ...

# %%
us_df = get_historical_data_by_region(kw_list,'IT',sleep=20)
print(us_df)
# Add region as a column 
#us_csv = us_df.to_csv(index=True)
# Out:
#                      Covid  Coronavirus  isPartial
# date
# 2019-10-01 00:00:00      0            0      False
# 2019-10-01 01:00:00      0            0      False
# 2019-10-01 02:00:00      0            0      False
# 2019-10-01 03:00:00      0            0      False
# 2019-10-01 04:00:00      0            0      False
# ...                    ...          ...        ...
# 2022-04-30 20:00:00     55           11      False
# 2022-04-30 21:00:00     56           11      False
# 2022-04-30 22:00:00     57            9      False
# 2022-04-30 23:00:00     56            9      False
# 2022-05-01 00:00:00     53            8      False
#
# [22260 rows x 3 columns]

# %%
us_df['Region'] = 'IT'
us_df = us_df.drop(columns='isPartial')

# %%
us_df
# Out:
#                      Covid  Coronavirus Region
# date
# 2019-10-01 00:00:00      0            0     IT
# 2019-10-01 01:00:00      0            0     IT
# 2019-10-01 02:00:00      0            0     IT
# 2019-10-01 03:00:00      0            0     IT
# 2019-10-01 04:00:00      0            0     IT
# ...                    ...          ...    ...
# 2022-04-30 20:00:00     55           11     IT
# 2022-04-30 21:00:00     56           11     IT
# 2022-04-30 22:00:00     57            9     IT
# 2022-04-30 23:00:00     56            9     IT
# 2022-05-01 00:00:00     53            8     IT
#
# [22260 rows x 3 columns]

# %%
us_csv = us_df.to_csv('IT_data.csv', index=True)
